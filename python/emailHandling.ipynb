# %%
import smtplib

# %%
smtp_object = smtplib.SMTP('smtp.gmail.com', 587) # 587 port => TLS encryption 
# 465 port (SSL) can also be used if this doesn't work

# %%
smtp_object.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [59.98.30.123]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
smtp_object.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
import getpass

# %%
password = getpass.getpass('Password Please: ') # Never save raw passwords anywhere.

# %% [markdown]
# # Using app password
# wqgh wegg vkbp zxlq

# %%
# email = getpass.getpass("Email: ")
email = 'b.anshuman1305@gmail.com'
# password = getpass.getpass("Password: ")
# password = 'was something'
smtp_object.login(email, password)
# Out:
# (235, b'2.7.0 Accepted')

# %%
from_address = email
to_address = 'b.a.13.official@gmail.com'
# subject = input("Enter the subject: ")
subject = 'Hola, from a script!'
# message = input("Enter the body: ")
message = "This message isn't autogenerated, but still, from a script!"
msg = "Subject: "+subject+"\n"+message #Such format is necessary

# %%
smtp_object.sendmail(from_address, to_address, msg) #Output as an empty dictionary indicates a successful transmission.
# Out:
# {}

# %%
subject = 'Mongoose'
message = 'Mongoose are dominating the world.'
msg = 'Subject: '+subject+'\n'+message

smtp_object.sendmail(from_address, to_address, msg)
# Out:
# {}

# %% [markdown]
# # Receiving Mails with Python!

# %%
import imaplib # For searching inbox
import email

# %% [markdown]
# <table border='1' >
#     <tr >
#         <th align='center'>Keyword </th>
#         <th align='center'>Definition</th>
#     </tr>
#     <tr>
#         <td>'ALL'</td>
#         <td>
#         Returns all messages in your email folder. Often there are size limits from imaplib.
#         To change these use imaplib._MAXLINE = 100 , where 100 is whatever you want the limit to be.
#         </td>
#     </tr>
#     <tr>
#         <td>'BEFORE date'</td>
#         <td>
#         Returns all messages before the date. Date must be formatted as 01-Nov-2000.
#         </td>
#     </tr>
#      <tr>
#         <td>'ON date'</td>
#         <td>
#         Returns all messages on the date. Date must be formatted as 01-Nov-2000.
#         </td>
#     </tr>
#      <tr>
#         <td>'SINCE date'</td>
#         <td>
#         Returns all messages after the date. Date must be formatted as 01-Nov-2000.
#         </td>
#     </tr>
#     <tr>
#         <td>'FROM some_string '</td>
#         <td>
#         Returns all from the sender in the string. String can be an email, for example 'FROM               user@example.com' or just a string that may appear in the email, "FROM example"
#         </td>
#     </tr>
#     <tr>
#         <td>'TO some_string'</td>
#         <td>
#         Returns all outgoing email to the email in the string. String can be an email, for example 'FROM user@example.com' or just a string that may appear in the email, "FROM example"
#         </td>
#     </tr>
#     <tr>
#         <td>'CC some_string' and/or 'BCC some_string'</td>
#         <td>
#         Returns all messages in your email folder. Often there are size limits from imaplib.
#         To change these use imaplib._MAXLINE = 100 , where 100 is whatever you want the limit to be.
#         </td>
#     </tr>
#     <tr>
#         <td>'SUBJECT string','BODY string','TEXT "string with spaces"'</td>
#         <td>
#         Returns all messages with the subject string or the string in the body of the email. If the string you are searching for has spaces in it, wrap it in double quotes.
#         </td>
#     </tr>
#     <tr>
#         <td>'SEEN', 'UNSEEN'</td>
#         <td>
#         Returns all messages that have been seen or unseen. (Also known as read or unread)
#         </td>
#     </tr>
#         <tr>
#         <td>'ANSWERED', 'UNANSWERED'</td>
#         <td>
#         Returns all messages that have been replied to or unreplied to.
#         </td>
#     </tr>
#         <tr>
#         <td>'DELETED', 'UNDELETED'</td>
#         <td>
#         Returns all messages that have been deleted or that have not been deleted.
#         </td>
#     </tr>
#
#
# </table>

# %%
M = imaplib.IMAP4_SSL('imap.gmail.com')

# %%
email = getpass.getpass('Email:')

# %%
password = getpass.getpass('Password: ')

# %%
M.login(email, password)
# Out:
# ('OK', [b'b.anshuman1305@gmail.com authenticated (Success)'])

# %%
M.list()
# Out:
# ('OK',
#  [b'(\\HasNoChildren) "/" "INBOX"',
#   b'(\\HasChildren) "/" "Mailspring"',
#   b'(\\HasNoChildren) "/" "Mailspring/Snoozed"',
#   b'(\\HasChildren \\Noselect) "/" "[Gmail]"',
#   b'(\\All \\HasNoChildren) "/" "[Gmail]/All Mail"',
#   b'(\\Drafts \\HasNoChildren) "/" "[Gmail]/Drafts"',
#   b'(\\HasNoChildren \\Important) "/" "[Gmail]/Important"',
#   b'(\\HasNoChildren \\Sent) "/" "[Gmail]/Sent Mail"',
#   b'(\\HasNoChildren \\Junk) "/" "[Gmail]/Spam"',
#   b'(\\Flagged \\HasNoChildren) "/" "[Gmail]/Starred"',
#   b'(\\HasNoChildren \\Trash) "/" "[Gmail]/Trash"'])

# %%
M.select('inbox')
# Out:
# ('OK', [b'9444'])

# %%
typ, data = M.search(None, 'FROM hsm.mishra@gmail.com')

# %%
typ
# Out:
# 'OK'

# %%
data
# Out:
# [b'1976']

# %%
email_id = data[0]

# %%
email_id
# Out:
# b'1976'

# %%
result, email_data = M.fetch(email_id, '(RFC822)')

# %%
result
# Out:
# 'OK'

# %%
email_data
# Out:
# [(b'1976 (RFC822 {62880}',
#   b'Delivered-To: b.anshuman1305@gmail.com\r\nReceived: by 10.223.188.1 with SMTP id s1csp3305505wrg;\r\n        Mon, 25 Sep 2017 23:04:24 -0700 (PDT)\r\nX-Received: by 10.202.84.11 with SMTP id i11mr11744017oib.152.1506405864398;\r\n        Mon, 25 Sep 2017 23:04:24 -0700 (PDT)\r\nARC-Seal: i=1; a=rsa-sha256; t=1506405864; cv=none;\r\n        d=google.com; s=arc-20160816;\r\n        b=\r\nARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com; s=arc-20160816;\r\n        h=to:subject:message-id:date:from:mime-version:dkim-signature\r\n         :arc-authentication-results;\r\n        bh=vDmM8O9YtWnAX5sL1Hk4bnbelHvHwf7Z8oClAfCYzH8=;\r\n        b=\r\nARC-Authentication-Results: i=1; mx.google.com;\r\n       dkim=pass header.i=@gmail.com header.s=20161025 header.b=JPRJUM/x;\r\n       spf=pass (google.com: domain of hsm.mishra@gmail.com designates 209.85.220.41 as permitted sender) smtp.mailfrom=hsm.mishra@gmail.com;\r\n       dmarc=pass (p=NONE sp=NONE dis=NONE) header.from=gmail.com\r\nReturn-Path: <hsm.mishra@gmail.com>\r\nReceived: from mail-sor-f41.google.com (mail-sor-f41.google.com. [209.85.220.41])\r\n        by mx.google.com with SMTPS id i69sor3578113oib.168.2017.09.25.23.04.24\r\n        for <b.anshuman1305@gmail.com>\r\n        (Google Transport Security);\r\n        Mon, 25 Sep 2017 23:04:24 -0700 (PDT)\r\nReceived-SPF: pass (google.com: domain of hsm.mishra@gmail.com designates 209.85.220.41 as permitted sender) client-ip=209.85.220.41;\r\nAuthentication-Results: mx.google.com;\r\n       dkim=pass header.i=@gmail.com header.s=20161025 header.b=JPRJUM/x;\r\n       spf=pass (google.com: domain of hsm.mishra@gmail.com designates 209.85.220.41 as permitted sender) smtp.mailfrom=hsm.mishra@gmail.com;\r\n       dmarc=pass (p=NONE sp=NONE dis=NONE) header.from=gmail.com\r\nDKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed;\r\n        d=gmail.com; s=20161025;\r\n        h=mime-version:from:date:message-id:subject:to;\r\n        bh=vDmM8O9YtWnAX5sL1Hk4bnbelHvHwf7Z8oClAfCYzH8=;\r\n        b=\r\nX-Google-DKIM-Signature: v=1; a=rsa-sha256; c=relaxed/relaxed;\r\n        d=1e100.net; s=20161025;\r\n        h=x-gm-message-state:mime-version:from:date:message-id:subject:to;\r\n        bh=vDmM8O9YtWnAX5sL1Hk4bnbelHvHwf7Z8oClAfCYzH8=;\r\n        b=\r\nX-Gm-Message-State: AHPjjUjbLDFQIOxFovZOTD3IZJMD+R+Jw5LXpIB ...
#  b')']

# %%
raw_email = email_data[0][1]

# %%
raw_email_string = raw_email.decode('utf-8')

# %%
import email

# %%
email_message = email.message_from_string(raw_email_string)

# %%
email_message

# %%
for part in email_message.walk():
    if part.get_content_type()=='text/html':
        body = part.get_payload(decode=True)
        print(body)
# Out:
# b'<div dir="ltr"><br></div>\r\n'
